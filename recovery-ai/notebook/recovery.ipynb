# %% [markdown]
# # Recovery AI Pipeline
#
# This notebook documents the local scrape -> clean -> label -> train -> infer workflow established in Step 1.

# %%
from pathlib import Path
root = Path.cwd().resolve().parents[0]
root / 'data'
